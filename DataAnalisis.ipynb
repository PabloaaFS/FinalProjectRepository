# %%
import pandas as pd
import mysql.connector
import matplotlib.pyplot as plt
from utils import load_data_tables, top_5_antiguos, top_5_recientes, distribucion_anios, altas_por_anio, bajas_por_anios, crec_decrec_2_anios, solt_vs_casado, edad_por_empleado, edad_media, desv_tipica, proyectos_activos, proyectos_finalizados, proyectos_total, distribucion_duracion, distribucion_lugar

# %%
# Establecer la conexión con la base de datos MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="practica"
)

# %%
empleados_df = load_data_tables(conn=conn, table="em_empleados")
# Out:
# C:\Users\paalvarez\Desktop\DEVELOPMENT\WORKSPACE\PROYECTO FINAL\fsgestiondatos\utils.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
empleados_df
# Out:
#     ID_EMPLEADO     TX_NIF TX_NOMBRE TX_APELLIDO1 TX_APELLIDO2 F_NACIMIENTO  \
# 0             1  33445566I     Pablo      Sarabia       García   1992-05-11
# 1             2  77889900J      Ever       Banega     Valencia   1988-06-29
# 2             3  99001122H      Gary        Medel         Soto   1987-08-03
# 3             4  55667788G    Daniel      Carriço     Da Silva   1988-08-04
# 4             5  11223344F     Julen    Lopetegui       Argote   1966-08-28
# 5             6  24681357D    Renato       Dirnei     Floriani   1979-10-20
# 6             7  13579246C    Carlos        Bacca      Ahumada   1986-09-08
# 7             8  87654321B      Ivan      Rakitic        Savic   1988-03-10
# 8             9  77889900O  Frédéric        Oumar      Kanouté   1977-09-02
# 9            10  99001122M     Diego       Carlos       Santos   1993-03-15
# 10           11  55667788L     Jesús        Navas     González   1985-11-21
# ...

# %%
top_5_empleadosantiguos = top_5_antiguos(empleados_df=empleados_df)

# %%
print(top_5_empleadosantiguos)
# Out:
#     ID_EMPLEADO     TX_NIF TX_NOMBRE TX_APELLIDO1 TX_APELLIDO2 F_NACIMIENTO  \
# 14           17  34455667U     Diego      Armando     Maradona   1960-10-30
# 13           16  22332233J    Javier      Navarro      Vazquez   1983-03-12
# 11           12  87564321P     Julio     Baptista      DaSilva   1983-10-23
# 10           11  55667788L     Jesús        Navas     González   1985-11-21
# 5             6  24681357D    Renato       Dirnei     Floriani   1979-10-20
#
#    N_TELEFONO1 N_TELEFONO2               TX_EMAIL      F_ALTA      F_BAJA  \
# 14   101010101   111111110     maradona@gmail.com  1992-08-14        None
# 13   654321123   678978098  javinavarro@gmail.com  2000-09-23        None
# 11   433522666   435665787     baptista@gmail.com  2001-01-01  2024-04-21
# 10   444555666   555666777        navas@gmail.com  2003-01-01  2024-04-21
# 5    777777777   888888888       renato@gmail.com  2005-07-01        None
#
#    CX_EDOCIVIL B_SERVMILITAR
# 14           S             N
# ...

# %%
top_5_recientes = top_5_recientes(empleados_df=empleados_df)

# %%
print(top_5_recientes)
# Out:
#     ID_EMPLEADO     TX_NIF TX_NOMBRE TX_APELLIDO1 TX_APELLIDO2 F_NACIMIENTO  \
# 18           23  89876576E    Lucas       Ocampos         Ruiz   1993-03-12
# 12           14  99999999N    Alvaro      Negredo       Teulon   1989-02-16
# 17           22  25432435I     Diego        Capel       Garcia   1989-09-08
# 9            10  99001122M     Diego       Carlos       Santos   1993-03-15
# 15           19  19191919W    Wissam          Ben       Yedder   1994-04-17
#
#    N_TELEFONO1 N_TELEFONO2             TX_EMAIL      F_ALTA      F_BAJA  \
# 18   234234234   456456456    ocampos@gmail,com  2023-05-09  2024-04-23
# 12   678876678   654456654    negredo@gmail.com  2022-07-13        None
# 17   546364532   234432212      capel@gmail.com  2021-09-07        None
# 9    666777888   777888999    dcarlos@gmail.com  2020-07-01  2024-04-21
# 15   697868754   654345213  benyedder@gmail.com  2019-08-16        None
#
#    CX_EDOCIVIL B_SERVMILITAR
# 18           C             S
# ...

# %%
distribucion_anios = distribucion_anios(empleados_df=empleados_df)

# %%
altas_por_anio = altas_por_anio(empleados_df=empleados_df)

# %% [raw]
# bajas_por_anios = bajas_por_anios(empleados_df=empleados_df)

# %%
print(bajas_por_anios)
# Out:
# <function bajas_por_anios at 0x000001BA702861F0>

# %%
crec_decrec_2_anios = crec_decrec_2_anios(empleados_df=empleados_df)

# %%
print(crec_decrec_2_anios)
# Out:
# F_BAJA
# 2024.0   NaN
# Name: count, dtype: float64

# %%
solt_vs_casado = solt_vs_casado(empleados_df=empleados_df)

# %%
print(solt_vs_casado)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
edad_por_empleado = edad_por_empleado(empleados_df=empleados_df)

# %%
print(edad_por_empleado)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
edad_media = edad_media(empleados_df=empleados_df)

# %%
print(edad_media)
# Out:
# 39.578947368421055

# %%
desv_tipica = desv_tipica(empleados_df=empleados_df)

# %%
print(desv_tipica)
# Out:
# 8.8525940295843

# %%
proyectos_df = load_data_tables(conn=conn, table="pr_proyectos")
# Out:
# C:\Users\paalvarez\Desktop\DEVELOPMENT\WORKSPACE\PROYECTO FINAL\fsgestiondatos\utils.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
proyectos_df
# Out:
#    ID_PROYECTO     TX_DESCRIPCIÓN    F_INICIO       F_FIN      F_BAJA  \
# 0            1               Liga  2023-08-21  2024-06-20        None
# 1            3      Europa League  2023-07-10  2024-05-13        None
# 2            4  Conference League  2023-05-10  2024-07-29        None
# 3            5   Champions League  2023-08-10  2024-06-01        None
# 4            8           Eurocopa  2024-06-15  2024-08-12        None
# 5            9       Copa del Rey  2022-09-10  2023-04-13  2024-04-21
# 6           10            Mundial  2022-06-13  2022-08-17  2024-04-21
# 7           11  La Liga Smartbank  2022-08-08  2023-06-17  2024-04-21
# 8           12   Juegos Olimpicos  2024-08-12  2024-10-13        None
# 9           13                nba  2024-04-02  2024-09-20        None
#
#                         TX_LUGAR  \
# 0  Estadio Ramon Sanchez Pizjuan
# 1           Estadio Dublin Arena
# 2            Estadio Agia Sophia
# 3                Estadio Wembley
# ...

# %%
proyectos_activos = proyectos_activos(proyectos_df=proyectos_df)

# %%
print(proyectos_activos)
# Out:
# 7

# %%
proyectos_finalizados = proyectos_finalizados(proyectos_df=proyectos_df)

# %%
print(proyectos_finalizados)
# Out:
# 3

# %%
proyectos_total = proyectos_total(proyectos_df=proyectos_df)

# %%
print(proyectos_total)
# Out:
# 10

# %%
distribucion_duracion = distribucion_duracion(proyectos_df=proyectos_df)

# %%
print(distribucion_duracion)
# Out:
# None

# %%
distribucion_lugar = distribucion_lugar(proyectos_df=proyectos_df)

# %%
print(distribucion_lugar)
# Out:
# Axes(0.125,0.11;0.775x0.77)
